# %% [markdown]
# # <center> Analisa Menjelang Piala Dunia </center>
#
# oleh : Ferdinand Winstein
#
# [Dataset](https://www.kaggle.com/code/raphaelmarconato/world-cup-2022-eda/data)
#
# ![70920-logo-piala-dunia-2022-qatar-1.jpg](attachment:70920-logo-piala-dunia-2022-qatar-1.jpg)

# %% [markdown]
# # Step 1. Persiapkan Dataset dan Package

# %%
#Package
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#Dataset

df = pd.read_csv('international_matches.csv')
df.head()
# Out:
#          date home_team     away_team home_team_continent away_team_continent  \
# 0  1993-08-08   Bolivia       Uruguay       South America       South America
# 1  1993-08-08    Brazil        Mexico       South America       North America
# 2  1993-08-08   Ecuador     Venezuela       South America       South America
# 3  1993-08-08    Guinea  Sierra Leone              Africa              Africa
# 4  1993-08-08  Paraguay     Argentina       South America       South America
#
#    home_team_fifa_rank  away_team_fifa_rank  home_team_total_fifa_points  \
# 0                   59                   22                            0
# 1                    8                   14                            0
# 2                   35                   94                            0
# 3                   65                   86                            0
# 4                   67                    5                            0
#
#    away_team_total_fifa_points  home_team_score  ...  shoot_out  \
# 0                            0                3  ...         No
# 1                            0                1  ...         No
# 2                            0                5  ...         No
# 3                            0                1  ...         No
# 4                            0                1  ...         No
#
#   home_team_result home_team_goalkeeper_score away_team_goalkeeper_score  \
# 0              Win                        NaN                        NaN
# 1             Draw                        NaN                        NaN
# 2              Win                        NaN                        NaN
# 3              Win                        NaN                        NaN
# 4             Lose                        NaN                        NaN
#
#    home_team_mean_defense_score home_team_mean_offense_score  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
#
#   home_team_mean_midfield_score  away_team_mean_defense_score  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#    away_team_mean_offense_score  away_team_mean_midfield_score
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
#
# [5 rows x 25 columns]

# %%
# melihat isi tiap kolom dari dataset (menentukan perlu cleaning bagian mana)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23921 entries, 0 to 23920
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   date                           23921 non-null  object
#  1   home_team                      23921 non-null  object
#  2   away_team                      23921 non-null  object
#  3   home_team_continent            23921 non-null  object
#  4   away_team_continent            23921 non-null  object
#  5   home_team_fifa_rank            23921 non-null  int64
#  6   away_team_fifa_rank            23921 non-null  int64
#  7   home_team_total_fifa_points    23921 non-null  int64
#  8   away_team_total_fifa_points    23921 non-null  int64
#  9   home_team_score                23921 non-null  int64
#  10  away_team_score                23921 non-null  int64
#  11  tournament                     23921 non-null  object
#  12  city                           23921 non-null  object
#  13  country                        23921 non-null  object
#  14  neutral_location               23921 non-null  bool
#  15  shoot_out                      23921 non-null  object
#  16  home_team_result               23921 non-null  object
#  17  home_team_goalkeeper_score     8379 non-null   float64
#  18  away_team_goalkeeper_score     8095 non-null   float64
#  19  home_team_mean_defense_score   7787 non-null   float64
#  20  home_team_mean_offense_score   8510 non-null   float64
#  21  home_team_mean_midfield_score  8162 non-null   float64
#  22  away_team_mean_defense_score   7564 non-null   float64
#  23  away_team_mean_offense_score   8312 non-null   float64
#  24  away_team_mean_midfield_score  7979 non-null   float64
# dtypes: bool(1), float64(8), int64(6), object(10)
# memory usage: 4.4+ MB

# %%
# melihat statistik deskriptif dari dataset

df.describe().round()
# Out:
#        home_team_fifa_rank  away_team_fifa_rank  home_team_total_fifa_points  \
# count              23921.0              23921.0                      23921.0
# mean                  78.0                 81.0                        323.0
# std                   52.0                 53.0                        501.0
# min                    1.0                  1.0                          0.0
# 25%                   33.0                 36.0                          0.0
# 50%                   71.0                 73.0                          0.0
# 75%                  115.0                119.0                        547.0
# max                  211.0                211.0                       2164.0
#
#        away_team_total_fifa_points  home_team_score  away_team_score  \
# count                      23921.0          23921.0          23921.0
# mean                         315.0              2.0              1.0
# std                          491.0              2.0              1.0
# min                            0.0              0.0              0.0
# 25%                            0.0              0.0              0.0
# 50%                            0.0              1.0              1.0
# 75%                          523.0              2.0              2.0
# max                         2164.0             31.0             21.0
#
#        home_team_goalkeeper_score  away_team_goalkeeper_score  \
# count                      8379.0                      8095.0
# mean                         75.0                        74.0
# std                           8.0                         8.0
# min                          47.0                        47.0
# 25%                          70.0                        69.0
# 50%                          75.0                        74.0
# 75%                          81.0                        80.0
# max                          97.0                        97.0
#
#        home_team_mean_defense_score  home_team_mean_offense_score  \
# count                        7787.0                        8510.0
# mean                           75.0                          76.0
# std                             6.0                           6.0
# min                            53.0                          53.0
# 25%                            71.0                          72.0
# 50%                            75.0                          76.0
# 75%                            79.0                          80.0
# max                            92.0                          93.0
#
#        home_team_mean_midfield_score  away_team_mean_defense_score  \
# count                         8162.0                        7564.0
# mean                            76.0                          74.0
# std                              6.0                           6.0
# min                             54.0                          53.0
# 25%                             72.0                          70.0
# 50%                             76.0                          74.0
# 75%                             80.0                          78.0
# max                             93.0                          92.0
#
#        away_team_mean_offense_score  away_team_mean_midfield_score
# count                        8312.0                         7979.0
# mean                           75.0                           75.0
# std                             6.0                            6.0
# min                            53.0                           54.0
# 25%                            71.0                           72.0
# 50%                            75.0                           76.0
# 75%                            80.0                           79.0
# max                            93.0                           93.0

# %% [markdown]
# # Step 2. Data Cleaning

# %% [markdown]
# ## Menghapus Kolom yang tidak dipakai

# %%
# kolom2 ini dirasa 'sampah' jadi kita delete

del df['away_team_continent']
del df['home_team_continent']

del df['tournament']
del df['city']
del df['country']
del df['neutral_location']

df
# Out:
#              date       home_team     away_team  home_team_fifa_rank  \
# 0      1993-08-08         Bolivia       Uruguay                   59
# 1      1993-08-08          Brazil        Mexico                    8
# 2      1993-08-08         Ecuador     Venezuela                   35
# 3      1993-08-08          Guinea  Sierra Leone                   65
# 4      1993-08-08        Paraguay     Argentina                   67
# ...           ...             ...           ...                  ...
# 23916  2022-06-14         Moldova       Andorra                  180
# 23917  2022-06-14   Liechtenstein        Latvia                  192
# 23918  2022-06-14           Chile         Ghana                   28
# 23919  2022-06-14           Japan       Tunisia                   23
# 23920  2022-06-14  Korea Republic         Egypt                   29
#
#        away_team_fifa_rank  home_team_total_fifa_points  \
# 0                       22                            0
# 1                       14                            0
# 2                       94                            0
# 3                       86                            0
# 4                        5                            0
# ...                    ...                          ...
# 23916                  153                          932
# 23917                  135                          895
# 23918                   60                         1526
# 23919                   35                         1553
# 23920                   32                         1519
#
#        away_team_total_fifa_points  home_team_score  away_team_score  \
# 0                                0                3                1
# 1                                0                1                1
# 2                                0                5                0
# 3                                0                1                0
# 4                                0                1                3
# ...                            ...              ...              ...
# 23916                         1040                2                1
# 23917                         1105                0                2
# 23918                         1387                0                0
# 23919                         1499                0                3
# 23920                         1500                4                1
#
#       shoot_out home_team_result  home_team_goalkeeper_score  \
# 0            No              Win                         NaN
# 1            No             Draw                         NaN
# 2            No              Win                         NaN
# 3            No              Win                         NaN
# 4            No             Lose                         NaN
# ...         ...              ...                         ...
# 23916        No              Win                        65.0
# 23917        No             Lose                         NaN
# 23918       Yes             Lose                        79.0
# 23919        No             Lose                        73.0
# 23920        No              Win                        75.0
#
#        away_team_goalkeeper_score  home_team_mean_defense_score  \
# 0                             NaN                           NaN
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             NaN                           NaN
# ...                           ...                           ...
# 23916                         NaN                           NaN
# 23917                        65.0                           NaN
# 23918                        74.0                          75.5
# 23919                         NaN                          75.2
# 23920                         NaN                          73.0
#
#        home_team_mean_offense_score  home_team_mean_midfield_score  \
# 0                               NaN                            NaN
# 1                               NaN                            NaN
# 2                               NaN                            NaN
# 3                               NaN                            NaN
# 4                               NaN                            NaN
# ...                             ...                            ...
# 23916                           NaN                            NaN
# 23917                           NaN                            NaN
# 23918                          76.7                           78.2
# 23919                          75.0                           77.5
# 23920                          80.0                           73.8
#
#        away_team_mean_defense_score  away_team_mean_offense_score  \
# 0                               NaN                           NaN
# 1                               NaN                           NaN
# 2                               NaN                           NaN
# 3                               NaN                           NaN
# 4                               NaN                           NaN
# ...                             ...                           ...
# 23916                           NaN                           NaN
# 23917                           NaN                           NaN
# 23918                          75.5                          76.0
# 23919                          70.8                          72.3
# 23920                           NaN                          79.3
#
#        away_team_mean_midfield_score
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 23916                            NaN
# 23917                            NaN
# 23918                           78.2
# 23919                           74.0
# 23920                           70.8
#
# [23921 rows x 19 columns]

# %% [markdown]
# ## Data 4 Tahun Terakhir
#
# Kita mengambil data pertandingan dari tahun 2019 saja, dengan harapan data-data ini adalah yang paling relevan

# %%
df = df[df['date'] > '2019-01-01']
df
# Out:
#              date             home_team  away_team  home_team_fifa_rank  \
# 20900  2019-01-02                  Oman   Thailand                   82
# 20901  2019-01-05  United Arab Emirates    Bahrain                   79
# 20902  2019-01-06              Thailand      India                  118
# 20903  2019-01-06             Australia     Jordan                   41
# 20904  2019-01-06                 Syria  Palestine                   74
# ...           ...                   ...        ...                  ...
# 23916  2022-06-14               Moldova    Andorra                  180
# 23917  2022-06-14         Liechtenstein     Latvia                  192
# 23918  2022-06-14                 Chile      Ghana                   28
# 23919  2022-06-14                 Japan    Tunisia                   23
# 23920  2022-06-14        Korea Republic      Egypt                   29
#
#        away_team_fifa_rank  home_team_total_fifa_points  \
# 20900                  118                         1295
# 20901                  113                         1309
# 20902                   97                         1160
# 20903                  109                         1436
# 20904                   99                         1322
# ...                    ...                          ...
# 23916                  153                          932
# 23917                  135                          895
# 23918                   60                         1526
# 23919                   35                         1553
# 23920                   32                         1519
#
#        away_team_total_fifa_points  home_team_score  away_team_score  \
# 20900                         1160                2                0
# 20901                         1178                1                1
# 20902                         1240                1                4
# 20903                         1196                0                1
# 20904                         1236                0                0
# ...                            ...              ...              ...
# 23916                         1040                2                1
# 23917                         1105                0                2
# 23918                         1387                0                0
# 23919                         1499                0                3
# 23920                         1500                4                1
#
#       shoot_out home_team_result  home_team_goalkeeper_score  \
# 20900        No              Win                        72.0
# 20901        No             Draw                         NaN
# 20902        No             Lose                         NaN
# 20903        No             Lose                        78.0
# 20904        No             Draw                         NaN
# ...         ...              ...                         ...
# 23916        No              Win                        65.0
# 23917        No             Lose                         NaN
# 23918       Yes             Lose                        79.0
# 23919        No             Lose                        73.0
# 23920        No              Win                        75.0
#
#        away_team_goalkeeper_score  home_team_mean_defense_score  \
# 20900                         NaN                           NaN
# 20901                         NaN                           NaN
# 20902                        63.0                           NaN
# 20903                         NaN                          73.2
# 20904                         NaN                           NaN
# ...                           ...                           ...
# 23916                         NaN                           NaN
# 23917                        65.0                           NaN
# 23918                        74.0                          75.5
# 23919                         NaN                          75.2
# 23920                         NaN                          73.0
#
#        home_team_mean_offense_score  home_team_mean_midfield_score  \
# 20900                           NaN                            NaN
# 20901                           NaN                            NaN
# 20902                           NaN                            NaN
# 20903                          69.7                           75.8
# 20904                           NaN                           69.2
# ...                             ...                            ...
# 23916                           NaN                            NaN
# 23917                           NaN                            NaN
# 23918                          76.7                           78.2
# 23919                          75.0                           77.5
# 23920                          80.0                           73.8
#
#        away_team_mean_defense_score  away_team_mean_offense_score  \
# 20900                           NaN                           NaN
# 20901                           NaN                           NaN
# 20902                          62.0                          63.7
# 20903                           NaN                           NaN
# 20904                           NaN                           NaN
# ...                             ...                           ...
# 23916                           NaN                           NaN
# 23917                           NaN                           NaN
# 23918                          75.5                          76.0
# 23919                          70.8                          72.3
# 23920                           NaN                          79.3
#
#        away_team_mean_midfield_score
# 20900                            NaN
# 20901                            NaN
# 20902                           60.0
# 20903                            NaN
# 20904                            NaN
# ...                              ...
# 23916                            NaN
# 23917                            NaN
# 23918                           78.2
# 23919                           74.0
# 23920                           70.8
#
# [3021 rows x 19 columns]

# %%
temp = df.sort_values(['home_team','date'], ascending =[True,False])
df['latest'] = temp.groupby('home_team').cumcount()+1
df = df[df['latest'] == 1].drop('latest',axis=1)
df
# Out:
# C:\Users\Winstein\AppData\Local\Temp\ipykernel_8876\571633946.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['latest'] = temp.groupby('home_team').cumcount()+1
#              date          home_team  away_team  home_team_fifa_rank  \
# 21128  2019-06-06             Bhutan       Guam                  186
# 21131  2019-06-06              Macau  Sri Lanka                  183
# 21222  2019-06-11  Brunei Darussalam   Mongolia                  194
# 21224  2019-06-11           Pakistan   Cambodia                  200
# 21360  2019-07-15              Tonga    Vanuatu                  202
# ...           ...                ...        ...                  ...
# 23916  2022-06-14            Moldova    Andorra                  180
# 23917  2022-06-14      Liechtenstein     Latvia                  192
# 23918  2022-06-14              Chile      Ghana                   28
# 23919  2022-06-14              Japan    Tunisia                   23
# 23920  2022-06-14     Korea Republic      Egypt                   29
#
#        away_team_fifa_rank  home_team_total_fifa_points  \
# 21128                  193                          917
# 21131                  202                          925
# 21222                  187                          903
# 21224                  173                          888
# 21360                  163                          868
# ...                    ...                          ...
# 23916                  153                          932
# 23917                  135                          895
# 23918                   60                         1526
# 23919                   35                         1553
# 23920                   32                         1519
#
#        away_team_total_fifa_points  home_team_score  away_team_score  \
# 21128                          907                1                0
# 21131                          886                1                0
# 21222                          915                2                1
# 21224                          967                1                2
# 21360                          997                0               14
# ...                            ...              ...              ...
# 23916                         1040                2                1
# 23917                         1105                0                2
# 23918                         1387                0                0
# 23919                         1499                0                3
# 23920                         1500                4                1
#
#       shoot_out home_team_result  home_team_goalkeeper_score  \
# 21128        No              Win                         NaN
# 21131        No              Win                         NaN
# 21222        No              Win                         NaN
# 21224        No             Lose                         NaN
# 21360        No             Lose                         NaN
# ...         ...              ...                         ...
# 23916        No              Win                        65.0
# 23917        No             Lose                         NaN
# 23918       Yes             Lose                        79.0
# 23919        No             Lose                        73.0
# 23920        No              Win                        75.0
#
#        away_team_goalkeeper_score  home_team_mean_defense_score  \
# 21128                         NaN                           NaN
# 21131                         NaN                           NaN
# 21222                         NaN                           NaN
# 21224                         NaN                           NaN
# 21360                         NaN                           NaN
# ...                           ...                           ...
# 23916                         NaN                           NaN
# 23917                        65.0                           NaN
# 23918                        74.0                          75.5
# 23919                         NaN                          75.2
# 23920                         NaN                          73.0
#
#        home_team_mean_offense_score  home_team_mean_midfield_score  \
# 21128                           NaN                            NaN
# 21131                           NaN                            NaN
# 21222                           NaN                            NaN
# 21224                           NaN                            NaN
# 21360                           NaN                            NaN
# ...                             ...                            ...
# 23916                           NaN                            NaN
# 23917                           NaN                            NaN
# 23918                          76.7                           78.2
# 23919                          75.0                           77.5
# 23920                          80.0                           73.8
#
#        away_team_mean_defense_score  away_team_mean_offense_score  \
# 21128                           NaN                           NaN
# 21131                           NaN                           NaN
# 21222                           NaN                           NaN
# 21224                           NaN                           NaN
# 21360                           NaN                           NaN
# ...                             ...                           ...
# 23916                           NaN                           NaN
# 23917                           NaN                           NaN
# 23918                          75.5                          76.0
# 23919                          70.8                          72.3
# 23920                           NaN                          79.3
#
#        away_team_mean_midfield_score
# 21128                            NaN
# 21131                            NaN
# 21222                            NaN
# 21224                            NaN
# 21360                            NaN
# ...                              ...
# 23916                            NaN
# 23917                            NaN
# 23918                           78.2
# 23919                           74.0
# 23920                           70.8
#
# [210 rows x 19 columns]

# %% [markdown]
# ## Tim yang bertanding
#
# Kita menggunakan / menghitung 32 tim yang ikut dalam piala dunia

# %%
teams_worldcup = ['Qatar', 'Ecuador', 'Senegal', 'Netherlands', 'England', 'Iran', 'USA', 
                  'Wales', 'Argentina', 'Saudi Arabia', 'Mexico', 'Poland', 'France',  
                  'Australia', 'Denmark', 'Tunisia', 'Spain', 'Costa Rica', 'Germany',  
                  'Japan', 'Belgium', 'Canada', 'Morocco', 'Croatia', 'Brazil', 'Serbia',  
                  'Switzerland', 'Cameroon', 'Portugal', 'Ghana', 'Uruguay', 'South Korea']

# %%
df = df[df['home_team'].isin(teams_worldcup)]
df
# Out:
#              date     home_team          away_team  home_team_fifa_rank  \
# 23497  2022-03-24        Brazil              Chile                    2
# 23516  2022-03-25      Cameroon            Algeria                   38
# 23615  2022-03-29         Qatar           Slovenia                   52
# 23656  2022-06-01         Ghana         Madagascar                   60
# 23667  2022-06-02       Tunisia  Equatorial Guinea                   35
# 23734  2022-06-05        Serbia           Slovenia                   25
# 23741  2022-06-05     Argentina            Estonia                    4
# 23753  2022-06-06       Croatia             France                   16
# 23764  2022-06-07       Senegal             Rwanda                   20
# 23794  2022-06-08       Belgium             Poland                    2
# 23805  2022-06-09        Canada            Curaçao                   38
# 23810  2022-06-09      Portugal     Czech Republic                    8
# 23821  2022-06-09  Saudi Arabia          Venezuela                   49
# 23822  2022-06-10           USA            Grenada                   15
# 23848  2022-06-11        Mexico           Suriname                    9
# 23853  2022-06-11         Wales            Belgium                   18
# 23861  2022-06-11       Ecuador         Cabo Verde                   46
# 23862  2022-06-11       Uruguay             Panama                   13
# 23866  2022-06-12         Spain     Czech Republic                    7
# 23867  2022-06-12   Switzerland           Portugal                   14
# 23876  2022-06-13     Australia               Peru                   42
# 23879  2022-06-13       Morocco            Liberia                   24
# 23884  2022-06-13       Denmark            Austria                   11
# 23885  2022-06-13        France            Croatia                    3
# 23890  2022-06-14    Costa Rica        New Zealand                   31
# 23906  2022-06-14       England            Hungary                    5
# 23907  2022-06-14       Germany              Italy                   12
# 23908  2022-06-14   Netherlands              Wales                   10
# 23909  2022-06-14        Poland            Belgium                   26
# 23919  2022-06-14         Japan            Tunisia                   23
#
#        away_team_fifa_rank  home_team_total_fifa_points  \
# 23497                   26                         1823
# 23516                   43                         1480
# 23615                   64                         1437
# 23656                  102                         1387
# 23667                   99                         1499
# 23734                   65                         1547
# 23741                  110                         1765
# 23753                    3                         1621
# 23764                  136                         1584
# 23794                   26                         1827
# 23805                   79                         1479
# 23810                   33                         1674
# 23821                   58                         1444
# 23822                  170                         1633
# 23848                  141                         1658
# 23853                    2                         1588
# 23861                   71                         1452
# 23862                   61                         1635
# 23866                   33                         1709
# 23867                    8                         1635
# 23876                   22                         1462
# 23879                  149                         1551
# 23884                   34                         1653
# 23885                   16                         1789
# 23890                  101                         1503
# 23906                   40                         1761
# 23907                    6                         1650
# 23908                   18                         1658
# 23909                    2                         1544
# 23919                   35                         1553
#
#        away_team_total_fifa_points  home_team_score  away_team_score  \
# 23497                         1543                4                0
# 23516                         1460                0                1
# 23615                         1375                0                0
# 23656                         1205                3                0
# 23667                         1210                4                0
# 23734                         1378                4                1
# 23741                         1169                5                0
# 23753                         1789                1                1
# 23764                         1097                1                0
# 23794                         1544                6                1
# 23805                         1298                4                0
# 23810                         1500                2                0
# 23821                         1398                0                1
# 23822                          968                5                0
# 23848                         1073                3                0
# 23853                         1827                1                1
# 23861                         1339                1                0
# 23862                         1382                5                0
# 23866                         1500                2                0
# 23867                         1674                1                0
# 23876                         1562                0                0
# 23879                         1050                2                0
# 23884                         1500                2                0
# 23885                         1621                0                1
# 23890                         1206                1                0
# 23906                         1466                0                4
# 23907                         1723                5                2
# 23908                         1588                3                2
# 23909                         1827                0                1
# 23919                         1499                0                3
#
#       shoot_out home_team_result  home_team_goalkeeper_score  \
# 23497        No              Win                        89.0
# 23516        No             Lose                        67.0
# 23615        No             Draw                         NaN
# 23656        No              Win                        74.0
# 23667        No              Win                         NaN
# 23734        No              Win                        80.0
# 23741        No              Win                        84.0
# 23753        No             Draw                        82.0
# 23764        No              Win                        83.0
# 23794        No              Win                        89.0
# 23805        No              Win                        76.0
# 23810        No              Win                        82.0
# 23821        No             Lose                        70.0
# 23822        No              Win                        77.0
# 23848        No              Win                        80.0
# 23853        No             Draw                        74.0
# 23861        No              Win                        71.0
# 23862        No              Win                        80.0
# 23866        No              Win                        84.0
# 23867        No              Win                        85.0
# 23876       Yes              Win                        77.0
# 23879        No              Win                        82.0
# 23884        No              Win                        85.0
# 23885        No             Lose                        87.0
# 23890        No              Win                        88.0
# 23906        No             Lose                        83.0
# 23907        No              Win                        90.0
# 23908        No              Win                        81.0
# 23909        No             Lose                        87.0
# 23919        No             Lose                        73.0
#
#        away_team_goalkeeper_score  home_team_mean_defense_score  \
# 23497                        79.0                          84.8
# 23516                        78.0                          76.8
# 23615                        91.0                           NaN
# 23656                         NaN                          75.5
# 23667                         NaN                          70.8
# 23734                        91.0                          75.8
# 23741                         NaN                          82.2
# 23753                        87.0                          77.8
# 23764                         NaN                          79.0
# 23794                        87.0                          80.8
# 23805                        74.0                          69.2
# 23810                        81.0                          85.2
# 23821                        73.0                          72.8
# 23822                         NaN                          75.8
# 23848                        69.0                          76.8
# 23853                        89.0                          75.0
# 23861                        62.0                          73.5
# 23862                        75.0                          81.2
# 23866                        81.0                          86.5
# 23867                        82.0                          78.5
# 23876                        74.0                          72.0
# 23879                         NaN                          81.2
# 23884                        74.0                          80.2
# 23885                        82.0                          84.2
# 23890                        68.0                          71.5
# 23906                        85.0                          85.0
# 23907                        89.0                          84.0
# 23908                        74.0                          85.2
# 23909                        89.0                          75.2
# 23919                         NaN                          75.2
#
#        home_team_mean_offense_score  home_team_mean_midfield_score  \
# 23497                          86.3                           85.5
# 23516                          77.7                           75.0
# 23615                           NaN                            NaN
# 23656                          76.0                           78.2
# 23667                          72.3                           74.0
# 23734                          80.3                           81.8
# 23741                          89.0                           84.0
# 23753                          76.7                           84.2
# 23764                          80.7                           79.0
# 23794                          85.7                           85.5
# 23805                          73.0                           78.0
# 23810                          86.0                           84.5
# 23821                          67.7                           72.8
# 23822                          77.7                           75.8
# 23848                          82.7                           78.2
# 23853                          73.0                           78.5
# 23861                          76.0                           74.5
# 23862                          84.3                           80.0
# 23866                          85.0                           86.0
# 23867                          76.7                           79.5
# 23876                          72.3                           73.5
# 23879                          81.7                           76.2
# 23884                          77.7                           80.2
# 23885                          88.3                           86.8
# 23890                          70.3                           69.2
# 23906                          88.0                           84.0
# 23907                          82.7                           87.8
# 23908                          83.0                           83.5
# 23909                          84.7                           75.8
# 23919                          75.0                           77.5
#
#        away_team_mean_defense_score  away_team_mean_offense_score  \
# 23497                          75.5                          76.7
# 23516                          78.0                          81.0
# 23615                          73.0                          77.0
# 23656                          70.5                           NaN
# 23667                           NaN                           NaN
# 23734                          73.0                          77.0
# 23741                           NaN                           NaN
# 23753                          84.2                          88.3
# 23764                           NaN                           NaN
# 23794                          75.2                          84.7
# 23805                           NaN                          67.7
# 23810                          77.8                          76.7
# 23821                          72.8                          76.3
# 23822                           NaN                           NaN
# 23848                          71.5                          68.3
# 23853                          80.8                          85.7
# 23861                          69.5                          76.3
# 23862                          69.8                          70.7
# 23866                          77.8                          76.7
# 23867                          85.2                          86.0
# 23876                          74.5                          73.0
# 23879                           NaN                          64.0
# 23884                          80.2                          77.0
# 23885                          77.8                          76.7
# 23890                          70.2                          70.7
# 23906                          75.5                          72.7
# 23907                          84.2                          85.3
# 23908                          75.0                          73.0
# 23909                          80.8                          85.7
# 23919                          70.8                          72.3
#
#        away_team_mean_midfield_score
# 23497                           78.2
# 23516                           78.0
# 23615                           76.2
# 23656                           67.5
# 23667                            NaN
# 23734                           76.2
# 23741                            NaN
# 23753                           86.8
# 23764                            NaN
# 23794                           75.8
# 23805                            NaN
# 23810                           78.5
# 23821                           77.8
# 23822                            NaN
# 23848                            NaN
# 23853                           85.5
# 23861                           69.8
# 23862                           67.5
# 23866                           78.5
# 23867                           84.5
# 23876                           76.8
# 23879                            NaN
# 23884                           80.8
# 23885                           84.2
# 23890                           69.2
# 23906                           73.0
# 23907                           84.5
# 23908                           78.5
# 23909                           85.5
# 23919                           74.0

# %% [markdown]
# # Step 3. Data Analysis and Visualisation

# %% [markdown]
# ## Analisa dengan `corr`

# %%
# melihat korelasi antar value

df.corr()
# Out:
# C:\Users\Winstein\AppData\Local\Temp\ipykernel_8876\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                home_team_fifa_rank  away_team_fifa_rank  \
# home_team_fifa_rank                       1.000000             0.208380
# away_team_fifa_rank                       0.208380             1.000000
# home_team_total_fifa_points              -0.949773            -0.234343
# away_team_total_fifa_points              -0.224410            -0.973802
# home_team_score                          -0.338878             0.286809
# away_team_score                          -0.224260            -0.418626
# home_team_goalkeeper_score               -0.687381            -0.185289
# away_team_goalkeeper_score               -0.248850            -0.568174
# home_team_mean_defense_score             -0.766009            -0.268270
# home_team_mean_offense_score             -0.751404            -0.112142
# home_team_mean_midfield_score            -0.738076            -0.417703
# away_team_mean_defense_score             -0.409361            -0.751715
# away_team_mean_offense_score             -0.150017            -0.772516
# away_team_mean_midfield_score            -0.393746            -0.861786
#
#                                home_team_total_fifa_points  \
# home_team_fifa_rank                              -0.949773
# away_team_fifa_rank                              -0.234343
# home_team_total_fifa_points                       1.000000
# away_team_total_fifa_points                       0.220327
# home_team_score                                   0.360805
# away_team_score                                   0.217338
# home_team_goalkeeper_score                        0.685564
# away_team_goalkeeper_score                        0.263080
# home_team_mean_defense_score                      0.790339
# home_team_mean_offense_score                      0.796273
# home_team_mean_midfield_score                     0.792481
# away_team_mean_defense_score                      0.335139
# away_team_mean_offense_score                      0.176033
# away_team_mean_midfield_score                     0.313969
#
#                                away_team_total_fifa_points  home_team_score  \
# home_team_fifa_rank                              -0.224410        -0.338878
# away_team_fifa_rank                              -0.973802         0.286809
# home_team_total_fifa_points                       0.220327         0.360805
# away_team_total_fifa_points                       1.000000        -0.296090
# home_team_score                                  -0.296090         1.000000
# away_team_score                                   0.406957        -0.235223
# home_team_goalkeeper_score                        0.205890         0.309986
# away_team_goalkeeper_score                        0.612900         0.055105
# home_team_mean_defense_score                      0.228810         0.169923
# home_team_mean_offense_score                      0.098998         0.287394
# home_team_mean_midfield_score                     0.392051         0.345935
# away_team_mean_defense_score                      0.807230        -0.075617
# away_team_mean_offense_score                      0.834652        -0.052437
# away_team_mean_midfield_score                     0.892439        -0.182172
#
#                                away_team_score  home_team_goalkeeper_score  \
# home_team_fifa_rank                  -0.224260                   -0.687381
# away_team_fifa_rank                  -0.418626                   -0.185289
# home_team_total_fifa_points           0.217338                    0.685564
# away_team_total_fifa_points           0.406957                    0.205890
# home_team_score                      -0.235223                    0.309986
# away_team_score                       1.000000                   -0.026897
# home_team_goalkeeper_score           -0.026897                    1.000000
# away_team_goalkeeper_score            0.383266                    0.374140
# home_team_mean_defense_score          0.242070                    0.548240
# home_team_mean_offense_score          0.172762                    0.582066
# home_team_mean_midfield_score         0.280192                    0.545252
# away_team_mean_defense_score          0.100745                    0.381545
# away_team_mean_offense_score          0.128927                    0.182717
# away_team_mean_midfield_score         0.097544                    0.300677
#
#                                away_team_goalkeeper_score  \
# home_team_fifa_rank                             -0.248850
# away_team_fifa_rank                             -0.568174
# home_team_total_fifa_points                      0.263080
# away_team_total_fifa_points                      0.612900
# home_team_score                                  0.055105
# away_team_score                                  0.383266
# home_team_goalkeeper_score                       0.374140
# away_team_goalkeeper_score                       1.000000
# home_team_mean_defense_score                     0.336442
# home_team_mean_offense_score                     0.386460
# home_team_mean_midfield_score                    0.567248
# away_team_mean_defense_score                     0.556224
# away_team_mean_offense_score                     0.638884
# away_team_mean_midfield_score                    0.558652
#
#                                home_team_mean_defense_score  \
# home_team_fifa_rank                               -0.766009
# away_team_fifa_rank                               -0.268270
# home_team_total_fifa_points                        0.790339
# away_team_total_fifa_points                        0.228810
# home_team_score                                    0.169923
# away_team_score                                    0.242070
# home_team_goalkeeper_score                         0.548240
# away_team_goalkeeper_score                         0.336442
# home_team_mean_defense_score                       1.000000
# home_team_mean_offense_score                       0.840795
# home_team_mean_midfield_score                      0.827394
# away_team_mean_defense_score                       0.321125
# away_team_mean_offense_score                       0.090708
# away_team_mean_midfield_score                      0.208474
#
#                                home_team_mean_offense_score  \
# home_team_fifa_rank                               -0.751404
# away_team_fifa_rank                               -0.112142
# home_team_total_fifa_points                        0.796273
# away_team_total_fifa_points                        0.098998
# home_team_score                                    0.287394
# away_team_score                                    0.172762
# home_team_goalkeeper_score                         0.582066
# away_team_goalkeeper_score                         0.386460
# home_team_mean_defense_score                       0.840795
# home_team_mean_offense_score                       1.000000
# home_team_mean_midfield_score                      0.763001
# away_team_mean_defense_score                       0.161172
# away_team_mean_offense_score                       0.038138
# away_team_mean_midfield_score                      0.127002
#
#                                home_team_mean_midfield_score  \
# home_team_fifa_rank                                -0.738076
# away_team_fifa_rank                                -0.417703
# home_team_total_fifa_points                         0.792481
# away_team_total_fifa_points                         0.392051
# home_team_score                                     0.345935
# away_team_score                                     0.280192
# home_team_goalkeeper_score                          0.545252
# away_team_goalkeeper_score                          0.567248
# home_team_mean_defense_score                        0.827394
# home_team_mean_offense_score                        0.763001
# home_team_mean_midfield_score                       1.000000
# away_team_mean_defense_score                        0.429452
# away_team_mean_offense_score                        0.315791
# away_team_mean_midfield_score                       0.365624
#
#                                away_team_mean_defense_score  \
# home_team_fifa_rank                               -0.409361
# away_team_fifa_rank                               -0.751715
# home_team_total_fifa_points                        0.335139
# away_team_total_fifa_points                        0.807230
# home_team_score                                   -0.075617
# away_team_score                                    0.100745
# home_team_goalkeeper_score                         0.381545
# away_team_goalkeeper_score                         0.556224
# home_team_mean_defense_score                       0.321125
# home_team_mean_offense_score                       0.161172
# home_team_mean_midfield_score                      0.429452
# away_team_mean_defense_score                       1.000000
# away_team_mean_offense_score                       0.810898
# away_team_mean_midfield_score                      0.901832
#
#                                away_team_mean_offense_score  \
# home_team_fifa_rank                               -0.150017
# away_team_fifa_rank                               -0.772516
# home_team_total_fifa_points                        0.176033
# away_team_total_fifa_points                        0.834652
# home_team_score                                   -0.052437
# away_team_score                                    0.128927
# home_team_goalkeeper_score                         0.182717
# away_team_goalkeeper_score                         0.638884
# home_team_mean_defense_score                       0.090708
# home_team_mean_offense_score                       0.038138
# home_team_mean_midfield_score                      0.315791
# away_team_mean_defense_score                       0.810898
# away_team_mean_offense_score                       1.000000
# away_team_mean_midfield_score                      0.778316
#
#                                away_team_mean_midfield_score
# home_team_fifa_rank                                -0.393746
# away_team_fifa_rank                                -0.861786
# home_team_total_fifa_points                         0.313969
# away_team_total_fifa_points                         0.892439
# home_team_score                                    -0.182172
# away_team_score                                     0.097544
# home_team_goalkeeper_score                          0.300677
# away_team_goalkeeper_score                          0.558652
# home_team_mean_defense_score                        0.208474
# home_team_mean_offense_score                        0.127002
# home_team_mean_midfield_score                       0.365624
# away_team_mean_defense_score                        0.901832
# away_team_mean_offense_score                        0.778316
# away_team_mean_midfield_score                       1.000000

# %% [markdown]
# ## Analisa dari fifa point
#
# Menganalisa kekuatan masing - masing tim berdasarkan Fifa Points mereka

# %%
fifa_point = df.nlargest(10,'home_team_total_fifa_points')
fifa_point
# Out:
#              date    home_team       away_team  home_team_fifa_rank  \
# 23794  2022-06-08      Belgium          Poland                    2
# 23497  2022-03-24       Brazil           Chile                    2
# 23885  2022-06-13       France         Croatia                    3
# 23741  2022-06-05    Argentina         Estonia                    4
# 23906  2022-06-14      England         Hungary                    5
# 23866  2022-06-12        Spain  Czech Republic                    7
# 23810  2022-06-09     Portugal  Czech Republic                    8
# 23848  2022-06-11       Mexico        Suriname                    9
# 23908  2022-06-14  Netherlands           Wales                   10
# 23884  2022-06-13      Denmark         Austria                   11
#
#        away_team_fifa_rank  home_team_total_fifa_points  \
# 23794                   26                         1827
# 23497                   26                         1823
# 23885                   16                         1789
# 23741                  110                         1765
# 23906                   40                         1761
# 23866                   33                         1709
# 23810                   33                         1674
# 23848                  141                         1658
# 23908                   18                         1658
# 23884                   34                         1653
#
#        away_team_total_fifa_points  home_team_score  away_team_score  \
# 23794                         1544                6                1
# 23497                         1543                4                0
# 23885                         1621                0                1
# 23741                         1169                5                0
# 23906                         1466                0                4
# 23866                         1500                2                0
# 23810                         1500                2                0
# 23848                         1073                3                0
# 23908                         1588                3                2
# 23884                         1500                2                0
#
#       shoot_out home_team_result  home_team_goalkeeper_score  \
# 23794        No              Win                        89.0
# 23497        No              Win                        89.0
# 23885        No             Lose                        87.0
# 23741        No              Win                        84.0
# 23906        No             Lose                        83.0
# 23866        No              Win                        84.0
# 23810        No              Win                        82.0
# 23848        No              Win                        80.0
# 23908        No              Win                        81.0
# 23884        No              Win                        85.0
#
#        away_team_goalkeeper_score  home_team_mean_defense_score  \
# 23794                        87.0                          80.8
# 23497                        79.0                          84.8
# 23885                        82.0                          84.2
# 23741                         NaN                          82.2
# 23906                        85.0                          85.0
# 23866                        81.0                          86.5
# 23810                        81.0                          85.2
# 23848                        69.0                          76.8
# 23908                        74.0                          85.2
# 23884                        74.0                          80.2
#
#        home_team_mean_offense_score  home_team_mean_midfield_score  \
# 23794                          85.7                           85.5
# 23497                          86.3                           85.5
# 23885                          88.3                           86.8
# 23741                          89.0                           84.0
# 23906                          88.0                           84.0
# 23866                          85.0                           86.0
# 23810                          86.0                           84.5
# 23848                          82.7                           78.2
# 23908                          83.0                           83.5
# 23884                          77.7                           80.2
#
#        away_team_mean_defense_score  away_team_mean_offense_score  \
# 23794                          75.2                          84.7
# 23497                          75.5                          76.7
# 23885                          77.8                          76.7
# 23741                           NaN                           NaN
# 23906                          75.5                          72.7
# 23866                          77.8                          76.7
# 23810                          77.8                          76.7
# 23848                          71.5                          68.3
# 23908                          75.0                          73.0
# 23884                          80.2                          77.0
#
#        away_team_mean_midfield_score
# 23794                           75.8
# 23497                           78.2
# 23885                           84.2
# 23741                            NaN
# 23906                           73.0
# 23866                           78.5
# 23810                           78.5
# 23848                            NaN
# 23908                           78.5
# 23884                           80.8

# %%
# Visualisasi 10 Tim dengan Fifa Point tertinggi

x = fifa_point['home_team']
y = fifa_point['home_team_total_fifa_points']

plt.figure(figsize=(12, 8), dpi = 100)

my_cmap = plt.get_cmap("viridis")
rescale = lambda y: (y - np.min(y)) / (np.max(y) - np.min(y))
plt.bar(x, y, color=my_cmap(rescale(y)))
    
plt.show()

# %% [markdown]
# ## Analisa dari Offense

# %%
offense_score = df.nlargest(10,'home_team_mean_offense_score')
offense_score
# Out:
#              date    home_team       away_team  home_team_fifa_rank  \
# 23741  2022-06-05    Argentina         Estonia                    4
# 23885  2022-06-13       France         Croatia                    3
# 23906  2022-06-14      England         Hungary                    5
# 23497  2022-03-24       Brazil           Chile                    2
# 23810  2022-06-09     Portugal  Czech Republic                    8
# 23794  2022-06-08      Belgium          Poland                    2
# 23866  2022-06-12        Spain  Czech Republic                    7
# 23909  2022-06-14       Poland         Belgium                   26
# 23862  2022-06-11      Uruguay          Panama                   13
# 23908  2022-06-14  Netherlands           Wales                   10
#
#        away_team_fifa_rank  home_team_total_fifa_points  \
# 23741                  110                         1765
# 23885                   16                         1789
# 23906                   40                         1761
# 23497                   26                         1823
# 23810                   33                         1674
# 23794                   26                         1827
# 23866                   33                         1709
# 23909                    2                         1544
# 23862                   61                         1635
# 23908                   18                         1658
#
#        away_team_total_fifa_points  home_team_score  away_team_score  \
# 23741                         1169                5                0
# 23885                         1621                0                1
# 23906                         1466                0                4
# 23497                         1543                4                0
# 23810                         1500                2                0
# 23794                         1544                6                1
# 23866                         1500                2                0
# 23909                         1827                0                1
# 23862                         1382                5                0
# 23908                         1588                3                2
#
#       shoot_out home_team_result  home_team_goalkeeper_score  \
# 23741        No              Win                        84.0
# 23885        No             Lose                        87.0
# 23906        No             Lose                        83.0
# 23497        No              Win                        89.0
# 23810        No              Win                        82.0
# 23794        No              Win                        89.0
# 23866        No              Win                        84.0
# 23909        No             Lose                        87.0
# 23862        No              Win                        80.0
# 23908        No              Win                        81.0
#
#        away_team_goalkeeper_score  home_team_mean_defense_score  \
# 23741                         NaN                          82.2
# 23885                        82.0                          84.2
# 23906                        85.0                          85.0
# 23497                        79.0                          84.8
# 23810                        81.0                          85.2
# 23794                        87.0                          80.8
# 23866                        81.0                          86.5
# 23909                        89.0                          75.2
# 23862                        75.0                          81.2
# 23908                        74.0                          85.2
#
#        home_team_mean_offense_score  home_team_mean_midfield_score  \
# 23741                          89.0                           84.0
# 23885                          88.3                           86.8
# 23906                          88.0                           84.0
# 23497                          86.3                           85.5
# 23810                          86.0                           84.5
# 23794                          85.7                           85.5
# 23866                          85.0                           86.0
# 23909                          84.7                           75.8
# 23862                          84.3                           80.0
# 23908                          83.0                           83.5
#
#        away_team_mean_defense_score  away_team_mean_offense_score  \
# 23741                           NaN                           NaN
# 23885                          77.8                          76.7
# 23906                          75.5                          72.7
# 23497                          75.5                          76.7
# 23810                          77.8                          76.7
# 23794                          75.2                          84.7
# 23866                          77.8                          76.7
# 23909                          80.8                          85.7
# 23862                          69.8                          70.7
# 23908                          75.0                          73.0
#
#        away_team_mean_midfield_score
# 23741                            NaN
# 23885                           84.2
# 23906                           73.0
# 23497                           78.2
# 23810                           78.5
# 23794                           75.8
# 23866                           78.5
# 23909                           85.5
# 23862                           67.5
# 23908                           78.5

# %%
x = offense_score['home_team']
y = offense_score['home_team_mean_offense_score']

plt.figure(figsize=(12, 8), dpi = 100)

my_cmap = plt.get_cmap("viridis")
rescale = lambda y: (y - np.min(y)) / (np.max(y) - np.min(y))
plt.bar(x, y, color=my_cmap(rescale(y)))
    
plt.show()

# %% [markdown]
# ## Apakah ada korelasi antara Fifa Point dengan Menang-Kalah
#
# Disini kita menganalisa 2 series data yakni Fifa Point tim dengan hasil pertandingan (menang, kalah, imbang)

# %%
# pertama, kita buat dulu fungsi untuk menentukan tim mana yang menang / kalah

def victory(home, away, home_score, away_score):
    if home_score > away_score:
        return home
    elif home_score < away_score:
        return away
    else:
        return 'Draw'

# %%
# kita tambahkan kolom winner yang berisi tim yang menang

df['winner'] = df.apply(lambda x : victory(x['home_team'],x['away_team'],
                                          x['home_team_score'],x['away_team_score']),axis=1)

# tampilkan
df[['home_team','away_team','winner']]
# Out:
# C:\Users\Winstein\AppData\Local\Temp\ipykernel_8876\322880833.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['winner'] = df.apply(lambda x : victory(x['home_team'],x['away_team'],
#           home_team          away_team       winner
# 23497        Brazil              Chile       Brazil
# 23516      Cameroon            Algeria      Algeria
# 23615         Qatar           Slovenia         Draw
# 23656         Ghana         Madagascar        Ghana
# 23667       Tunisia  Equatorial Guinea      Tunisia
# 23734        Serbia           Slovenia       Serbia
# 23741     Argentina            Estonia    Argentina
# 23753       Croatia             France         Draw
# 23764       Senegal             Rwanda      Senegal
# 23794       Belgium             Poland      Belgium
# 23805        Canada            Curaçao       Canada
# 23810      Portugal     Czech Republic     Portugal
# 23821  Saudi Arabia          Venezuela    Venezuela
# 23822           USA            Grenada          USA
# 23848        Mexico           Suriname       Mexico
# 23853         Wales            Belgium         Draw
# 23861       Ecuador         Cabo Verde      Ecuador
# 23862       Uruguay             Panama      Uruguay
# 23866         Spain     Czech Republic        Spain
# 23867   Switzerland           Portugal  Switzerland
# 23876     Australia               Peru         Draw
# 23879       Morocco            Liberia      Morocco
# 23884       Denmark            Austria      Denmark
# 23885        France            Croatia      Croatia
# 23890    Costa Rica        New Zealand   Costa Rica
# 23906       England            Hungary      Hungary
# 23907       Germany              Italy      Germany
# 23908   Netherlands              Wales  Netherlands
# 23909        Poland            Belgium      Belgium
# 23919         Japan            Tunisia      Tunisia

# %%
# kedua, kita buat  fungsi untuk menentukan tim mana yang memiliki fifa point lebih tinggi

def fifa_point_victory(home, away, home_point, away_point):
    if home_point > away_point:
        return home
    elif home_point < away_point:
        return away
    else:
        return 'Draw'

# %%
# sama dengan di atas, kita simpan data tim yang fifa point nya lebih tinggi di kolom better_fifa_points
df['better_fifa_points'] = df.apply(lambda x : fifa_point_victory(x['home_team'],x['away_team'],
                                          x['home_team_total_fifa_points'],x['away_team_total_fifa_points']),axis=1)

# tampilkan
df[['home_team','away_team','winner','better_fifa_points']]
# Out:
# C:\Users\Winstein\AppData\Local\Temp\ipykernel_8876\1115530124.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['better_fifa_points'] = df.apply(lambda x : fifa_point_victory(x['home_team'],x['away_team'],
#           home_team          away_team       winner better_fifa_points
# 23497        Brazil              Chile       Brazil             Brazil
# 23516      Cameroon            Algeria      Algeria           Cameroon
# 23615         Qatar           Slovenia         Draw              Qatar
# 23656         Ghana         Madagascar        Ghana              Ghana
# 23667       Tunisia  Equatorial Guinea      Tunisia            Tunisia
# 23734        Serbia           Slovenia       Serbia             Serbia
# 23741     Argentina            Estonia    Argentina          Argentina
# 23753       Croatia             France         Draw             France
# 23764       Senegal             Rwanda      Senegal            Senegal
# 23794       Belgium             Poland      Belgium            Belgium
# 23805        Canada            Curaçao       Canada             Canada
# 23810      Portugal     Czech Republic     Portugal           Portugal
# 23821  Saudi Arabia          Venezuela    Venezuela       Saudi Arabia
# 23822           USA            Grenada          USA                USA
# 23848        Mexico           Suriname       Mexico             Mexico
# 23853         Wales            Belgium         Draw            Belgium
# 23861       Ecuador         Cabo Verde      Ecuador            Ecuador
# 23862       Uruguay             Panama      Uruguay            Uruguay
# 23866         Spain     Czech Republic        Spain              Spain
# 23867   Switzerland           Portugal  Switzerland           Portugal
# 23876     Australia               Peru         Draw               Peru
# 23879       Morocco            Liberia      Morocco            Morocco
# 23884       Denmark            Austria      Denmark            Denmark
# 23885        France            Croatia      Croatia             France
# 23890    Costa Rica        New Zealand   Costa Rica         Costa Rica
# 23906       England            Hungary      Hungary            England
# 23907       Germany              Italy      Germany              Italy
# 23908   Netherlands              Wales  Netherlands        Netherlands
# 23909        Poland            Belgium      Belgium            Belgium
# 23919         Japan            Tunisia      Tunisia              Japan

# %%
# ketiga, kita buat fungsi yang menentukan apakah tim dengan fifa point lebih tinggi berhasil menang atau tidak

def fifa_point_result(winner, better_fifa_points):
    if winner == 'Draw':
        return winner
    elif winner == better_fifa_points:
        return 'Better'
    else:
        return 'Lower'

# %%
# simpan dalam kolom result_point
df['result_point'] = df.apply(lambda x : fifa_point_result(x['winner'],x['better_fifa_points']),axis=1)

# tampilkan
df[['home_team','away_team','winner','better_fifa_points','result_point']]
# Out:
# C:\Users\Winstein\AppData\Local\Temp\ipykernel_8876\350482908.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['result_point'] = df.apply(lambda x : fifa_point_result(x['winner'],x['better_fifa_points']),axis=1)
#           home_team          away_team       winner better_fifa_points  \
# 23497        Brazil              Chile       Brazil             Brazil
# 23516      Cameroon            Algeria      Algeria           Cameroon
# 23615         Qatar           Slovenia         Draw              Qatar
# 23656         Ghana         Madagascar        Ghana              Ghana
# 23667       Tunisia  Equatorial Guinea      Tunisia            Tunisia
# 23734        Serbia           Slovenia       Serbia             Serbia
# 23741     Argentina            Estonia    Argentina          Argentina
# 23753       Croatia             France         Draw             France
# 23764       Senegal             Rwanda      Senegal            Senegal
# 23794       Belgium             Poland      Belgium            Belgium
# 23805        Canada            Curaçao       Canada             Canada
# 23810      Portugal     Czech Republic     Portugal           Portugal
# 23821  Saudi Arabia          Venezuela    Venezuela       Saudi Arabia
# 23822           USA            Grenada          USA                USA
# 23848        Mexico           Suriname       Mexico             Mexico
# 23853         Wales            Belgium         Draw            Belgium
# 23861       Ecuador         Cabo Verde      Ecuador            Ecuador
# 23862       Uruguay             Panama      Uruguay            Uruguay
# 23866         Spain     Czech Republic        Spain              Spain
# 23867   Switzerland           Portugal  Switzerland           Portugal
# 23876     Australia               Peru         Draw               Peru
# 23879       Morocco            Liberia      Morocco            Morocco
# 23884       Denmark            Austria      Denmark            Denmark
# 23885        France            Croatia      Croatia             France
# 23890    Costa Rica        New Zealand   Costa Rica         Costa Rica
# 23906       England            Hungary      Hungary            England
# 23907       Germany              Italy      Germany              Italy
# 23908   Netherlands              Wales  Netherlands        Netherlands
# 23909        Poland            Belgium      Belgium            Belgium
# 23919         Japan            Tunisia      Tunisia              Japan
#
#       result_point
# 23497       Better
# 23516        Lower
# 23615         Draw
# 23656       Better
# 23667       Better
# 23734       Better
# 23741       Better
# 23753         Draw
# 23764       Better
# 23794       Better
# 23805       Better
# 23810       Better
# 23821        Lower
# 23822       Better
# 23848       Better
# 23853         Draw
# 23861       Better
# 23862       Better
# 23866       Better
# 23867        Lower
# 23876         Draw
# 23879       Better
# 23884       Better
# 23885        Lower
# 23890       Better
# 23906        Lower
# 23907        Lower
# 23908       Better
# 23909       Better
# 23919        Lower

# %%
# visualisasi 
plt.figure(figsize=(12, 8), dpi = 100) # mempersiapkan canvas / tempat dan ukuran chart
# figsize menentukan ukuran chart
# dpi menentukan kualitas gambar dari chart

total = len(df) # total banyaknya data
ax = sns.countplot(x='result_point',data=df) # membuat count plot dengan bantuan library seaborn
for p in ax.patches:
    perc = str(round(p.get_height()/total * 100,2))+'%' # menampilkan persentase (di line 7 kita mendapatkan nilai "count", bukan persentase)
    x,y = p.get_xy()
    ax.annotate(perc, (x+p.get_width(),y+p.get_height()),ha = 'center' ) # tampilkan nilai persentase
    
plt.show() # tampilkan chart

# %% [markdown]
# # Step 4. Conclusion

# %% [markdown]
# - Kita bisa melihat semakin tinggi Fifa Point suatu tim, jumlah kemenangan juga lebih tinggi
# - Ketika 2 tim bertanding, 63,33 % kejadian tim dengan fifa point lebih tinggi yang menang
# - sedangkan dalam 23,33% kejadian, tim dengan fifa point lebih rendah justru yang menang
# - dan hanya 13.33& kejadian, pertandingan berakhir imbang
#
# ## Dapat diambil kesimpulan, ketika ada 2 tim yang bertanding, tim dengan FIFA POINTS lebih tinggi memiliki kemungkinan menang yang lebih tinggi
